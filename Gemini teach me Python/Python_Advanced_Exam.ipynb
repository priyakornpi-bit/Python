# %% [markdown]
# # Python Advanced Examination - 100 Questions
#
# **Level:** Advanced (A-Level)
#
# **Instructions:**
# - Students must write all code themselves
# - No solutions provided
# - Deep thinking required before coding
# - Each question tests understanding, not memorization
# - Write your answer in the code cell below each question

# %% [markdown]
# ## Section 1: Variables & Data Types
#
# **Objective:** Master reference semantics and understand mutable vs immutable types.
#
# Shallow Test your comprehension of how Python variables reference objects, not store values.

# %% [markdown]
# ### Question 1.1
#
# อธิบายว่าทำไมโค้ดนี้ให้ผลลัพธ์ 4 แม้ว่า b += [4] ดูเหมือนจะสร้างตัวแปรใหม่
#
# ```python
# a = [1, 2]
# b = a
# a += [3, 4]
# print(len(b))
# ```

# %%
a = [1, 2]
b = a
a += [3, 4]
print(len(b))
#
# Out:
# 4

# %% [markdown]
# ### Question 1.2
#
# พยากรณ์เอาต์พุต อธิบายความแตกต่างระหว่าง = และ +=
#
# ```python
# x = [1, 2]
# y = x
# x = x + [3]
# print(y)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.3
#
# วิเคราะห์พฤติกรรมการคัดลอก: shallow vs deep
#
# ```python
# import copy
# a = [1, [2]]
# b = copy.copy(a)
# b[1].append(3)
# print(a)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.4
#
# หาข้อผิดพลาด: strings immutable
#
# ```python
# s = 'hello'
# s[0] = 'H'
# print(s)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.5
#
# สตริง interning - ปั่นว่า a is b
#
# ```python
# a = 'hello'
# b = 'hello'
# print(a is b, a == b)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.6
#
# None เป็น singleton
#
# ```python
# a = None
# b = None
# print(a is b)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.7
#
# Boolean-Integer equivalence
#
# ```python
# print(1 == True, 0 == False)
# print(1 is True, 0 is False)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.8
#
# Tuple mutability if contains mutable
#
# ```python
# t = (1, 2, [3, 4])
# t[2].append(5)
# print(t)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.9
#
# Dict key hashing: 1 vs 1.0
#
# ```python
# d = {1: 'int'}
# print(d[1.0], d.get(1.0))
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.10
#
# Set requires hashable
#
# ```python
# s = {1, 2}
# s.add([3])
# print(s)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.11
#
# Float precision issue
#
# ```python
# print(0.1 + 0.2 == 0.3)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.12
#
# Small integer caching
#
# ```python
# a = 256
# b = 256
# print(a is b)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.13
#
# Large integer no caching
#
# ```python
# a = 257
# b = 257
# print(a is b)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.14
#
# List slice creates shallow copy
#
# ```python
# a = [1, [2]]
# b = a[:]
# b[1].append(3)
# print(a)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 1.15
#
# Empty containers equality vs identity
#
# ```python
# a = []
# b = []
# print(a == b, a is b)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ## Section 2: Reference vs Value Assignment
#
# **Objective:** Understand assignment semantics and aliasing.

# %% [markdown]
# ### Question 2.1
#
# เปลี่ยนแปลงหนึ่ง ส่งผลต่ออย่างอื่น
#
# ```python
# x = {'key': [1]}
# y = x
# y['key'].append(2)
# print(x)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 2.2
#
# Reassignment breaks reference
#
# ```python
# x = [1, 2]
# y = x
# x = [3, 4]
# print(y)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 2.3
#
# Mutation vs Reassignment
#
# ```python
# a = [1, 2]
# b = a
# a.append(3)
# a = [4, 5]
# print(b)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 2.4
#
# Swap using tuple unpacking works
#
# ```python
# x = 1
# y = 2
# x, y = y, x
# print(x, y)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่

# %% [markdown]
# ### Question 2.5
#
# Modifying dict through key
#
# ```python
# d = {'a': 1}
# e = d
# e['a'] = 2
# print(d)
# ```

# %%
# TODO: เขียนคำตอบของคุณที่นี่
